# %% [markdown]
# <a href="https://colab.research.google.com/github/sabbir2014/tean08---CSE327/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# importing dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import DBSCAN

# %% [markdown]
# Data Collection and Analysis

# %%
Accidents.head()
# Out:
#   Reference Number  Grid Ref: Easting  ...  Sex of Casualty 7  Age of Casualty 7
# 0          6140231             398364  ...                NaN                NaN
# 1          6142035             407438  ...                NaN                NaN
# 2          6170291             409015  ...                NaN                NaN
# 3          6180214             409646  ...                NaN                NaN
# 4          6191021             407754  ...                NaN                NaN
#
# [5 rows x 45 columns]

# %%
# last five rows in the dataframe
Accidents.tail()

# %%
# finding the number of rows and columns
Accidents.shape

# %%
# checking for missing values
Accidents.isnull().sum()

# %%
print(Accidents)

# %% [markdown]
# Choosing Lighting Condition and Weather Condition Columns

# %%
X = Accidents.iloc[:,[5,14]].values

# %%
print(X)
# Out:
# [[ 701   19]
#  [2308   36]
#  [ 838   18]
#  [ 705   53]
#  [1515   23]
#  [1424   64]
#  [ 550   47]
#  [ 700   51]
#  [ 826   11]
#  [1445   43]
#  [1735   47]
#  [1905   33]
#  [1530   17]
#  [1807   40]
#  [1630   75]
#  [1026   20]
#  [1100   64]
#  [ 230   28]
#  [2125   28]
#  [1733   32]
#  [1757   25]
#  [1912    1]
#  [1032   36]
#  [1517   78]
#  [2205   33]
#  [ 900   49]
#  [1500   79]
#  [ 100   43]
#  [1800   40]
#  [1450   47]
#  [2011   18]
#  [ 540   38]
#  [2031   26]
#  [1225   35]
#  [1605   74]
#  [1510   32]
#  [1353   41]
#  [2252   29]
#  [1129   63]
#  [1415   86]
#  [1835   57]
#  [1400   49]
#  [1230   17]
#  [1650   19]
#  [1755   15]
#  [ 151   45]
#  [ 810   47]
#  [ 559   57]
#  [ 550   27]
#  [1148   62]
#  [1305   46]
#  [ 850   47]
#  [1500   61]
#  [1127   61]
#  [ 845   17]
#  [1730    5]
#  [2100   47]
#  [1715   35]
#  [1249   19]
#  [1501   43]
#  [1340   53]
#  [1645   54]
#  [1540   37]
#  [1803    8]
#  [1015   69]
#  [1900   47]
# ...

# %% [markdown]
# Choosing the number of cluster

# %%
clustering = DBSCAN(eps=50, min_samples=20).fit(x)

# %%
cluster = clustering.labels_

# %%
len(set(cluster))
# Out:
# 4
